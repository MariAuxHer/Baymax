# %%
import pandas as pd

# %%
endpoints = pd.read_csv('endpoint_pfile_20230821-20230827.csv')
endpoints
# Out:
#              NPI Endpoint Type Endpoint Type Description  \
# 0     1831147545        DIRECT  Direct Messaging Address
# 1     1952355794        DIRECT  Direct Messaging Address
# 2     1801021886          FHIR                  FHIR URL
# 3     1801021886          FHIR                  FHIR URL
# 4     1801021886        DIRECT  Direct Messaging Address
# ...          ...           ...                       ...
# 2685  1790933042          SOAP                  SOAP URL
# 2686  1295219483        OTHERS                 Other URL
# 2687  1740997543       CONNECT               CONNECT URL
# 2688  1588371215       CONNECT               CONNECT URL
# 2689  1174707947        DIRECT  Direct Messaging Address
#
#                                                Endpoint Affiliation  \
# 0                  nbhambhani119322@nyumc.direct-ci.com           N
# 1              acall309304@direct.rochesterregional.org           N
# 2     https://epicproxy-pub.et1089.epichosted.com/FH...           N
# ...

# %%
endpoints = endpoints[(endpoints['Endpoint Type'] != 'FHIR') & (endpoints['Endpoint Type'] != 'SOAP') & (endpoints['Endpoint Type'] != 'OTHERS')]
endpoints
# Out:
#              NPI Endpoint Type Endpoint Type Description  \
# 0     1831147545        DIRECT  Direct Messaging Address
# 1     1952355794        DIRECT  Direct Messaging Address
# 4     1801021886        DIRECT  Direct Messaging Address
# 5     1730568007        DIRECT  Direct Messaging Address
# 8     1942436258        DIRECT  Direct Messaging Address
# ...          ...           ...                       ...
# 2683  1073060646       CONNECT               CONNECT URL
# 2684  1215285374        DIRECT  Direct Messaging Address
# 2687  1740997543       CONNECT               CONNECT URL
# 2688  1588371215       CONNECT               CONNECT URL
# 2689  1174707947        DIRECT  Direct Messaging Address
#
#                                                Endpoint Affiliation  \
# 0                  nbhambhani119322@nyumc.direct-ci.com           N
# 1              acall309304@direct.rochesterregional.org           N
# 4                                crt4001@direct.nyp.org           N
# ...

# %%
add_cols = [
    "Affiliation Address Line One",
    "Affiliation Address Line Two",
    "Affiliation Address City",
    "Affiliation Address State",
    "Affiliation Address Country",
    "Affiliation Address Postal Code",
]

endpoints['Address'] = endpoints.apply(lambda row: ', '.join(map(str, row[add_cols].dropna())), axis=1)
endpoints
# Out:
# /tmp/ipykernel_13310/619260385.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   endpoints['Address'] = endpoints.apply(lambda row: ', '.join(map(str, row[add_cols].dropna())), axis=1)
#              NPI Endpoint Type Endpoint Type Description  \
# 0     1831147545        DIRECT  Direct Messaging Address
# 1     1952355794        DIRECT  Direct Messaging Address
# 4     1801021886        DIRECT  Direct Messaging Address
# 5     1730568007        DIRECT  Direct Messaging Address
# 8     1942436258        DIRECT  Direct Messaging Address
# ...          ...           ...                       ...
# 2683  1073060646       CONNECT               CONNECT URL
# 2684  1215285374        DIRECT  Direct Messaging Address
# ...

# %%
endpoints = endpoints.drop(columns=add_cols)
endpoints
# Out:
#              NPI Endpoint Type Endpoint Type Description  \
# 0     1831147545        DIRECT  Direct Messaging Address
# 1     1952355794        DIRECT  Direct Messaging Address
# 4     1801021886        DIRECT  Direct Messaging Address
# 5     1730568007        DIRECT  Direct Messaging Address
# 8     1942436258        DIRECT  Direct Messaging Address
# ...          ...           ...                       ...
# 2683  1073060646       CONNECT               CONNECT URL
# 2684  1215285374        DIRECT  Direct Messaging Address
# 2687  1740997543       CONNECT               CONNECT URL
# 2688  1588371215       CONNECT               CONNECT URL
# 2689  1174707947        DIRECT  Direct Messaging Address
#
#                                                Endpoint Affiliation  \
# 0                  nbhambhani119322@nyumc.direct-ci.com           N
# 1              acall309304@direct.rochesterregional.org           N
# 4                                crt4001@direct.nyp.org           N
# ...

# %%
taxonomy_set = pd.read_csv('nucc_taxonomy_231.csv', encoding='ISO-8859-1', dtype=str)
taxonomy_set
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
taxonomy_dict = {}

# Iterate through the rows of the DataFrame
for index, row in taxonomy_set.iterrows():
    code = row['Code']
    grouping = row['Grouping']
    classification = row['Classification']
    specialization = row['Specialization']

    # Check if the grouping exists in the dictionary
    if grouping not in taxonomy_dict:
        taxonomy_dict[grouping] = {}

    # Check if the classification exists in the grouping dictionary
    if classification not in taxonomy_dict[grouping]:
        taxonomy_dict[grouping][classification] = {}

    # Add the code under the classification
    if specialization:
        taxonomy_dict[grouping][classification][code] = specialization
    else:
        taxonomy_dict[grouping][classification][code] = None
        
taxonomy_dict
# Out:
# {'Group': {'Multi-Specialty': {'193200000X': nan},
#   'Single Specialty': {'193400000X': nan}},
#  'Allopathic & Osteopathic Physicians': {'Allergy & Immunology': {'207K00000X': nan,
#    '207KA0200X': 'Allergy',
#    '207KI0005X': 'Clinical & Laboratory Immunology'},
#   'Anesthesiology': {'207L00000X': nan,
#    '207LA0401X': 'Addiction Medicine',
#    '207LC0200X': 'Critical Care Medicine',
#    '207LH0002X': 'Hospice and Palliative Medicine',
#    '207LP2900X': 'Pain Medicine',
#    '207LP3000X': 'Pediatric Anesthesiology'},
#   'Clinical Pharmacology': {'208U00000X': nan},
#   'Colon & Rectal Surgery': {'208C00000X': nan},
#   'Dermatology': {'207N00000X': nan,
#    '207NI0002X': 'Clinical & Laboratory Dermatological Immunology',
#    '207ND0900X': 'Dermatopathology',
#    '207ND0101X': 'MOHS-Micrographic Surgery',
#    '207NP0225X': 'Pediatric Dermatology',
#    '207NS0135X': 'Procedural Dermatology'},
#   'Electrodiagnostic Medicine': {'204R00000X': nan},
# ...
