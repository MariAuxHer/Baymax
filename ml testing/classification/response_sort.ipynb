# %%
import numpy as np

# %%
def create_individual_files(input_file, output_dir):
    # Open the original text file for reading
    with open(input_file, 'r') as file:
        # Read lines from the file
        lines = file.readlines()

        # Create individual text files for each line
        for i, line in enumerate(lines):
            # Define the name for the individual file
            output_file = f'%s/{i + 1}.txt' % output_dir

            # Write the line to the individual file
            with open(output_file, 'w') as individual_file:
                individual_file.write(line.strip())

            print(f"Created {output_file}")

# %%
# neurology data conversion

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/neurology_train.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology'

# Call the function to create individual files
create_individual_files(input_file, output_dir)

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/neurology_test.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/neurology'

# Call the function to create individual files
create_individual_files(input_file, output_dir)
# Out:
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/1.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/2.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/3.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/4.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/5.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/6.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/7.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/8.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/9.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/neurology/10.txt
# ...

# %%
# podiatry data conversion

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/podiatry_train.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry'

# Call the function to create individual files
create_individual_files(input_file, output_dir)

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/podiatry_test.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/podiatry'

# Call the function to create individual files
create_individual_files(input_file, output_dir)
# Out:
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/1.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/2.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/3.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/4.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/5.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/6.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/7.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/8.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/9.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/podiatry/10.txt
# ...

# %%
# optometry data conversion

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/optometry_train.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry'

# Call the function to create individual files
create_individual_files(input_file, output_dir)

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/optometry_test.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/optometry'

# Call the function to create individual files
create_individual_files(input_file, output_dir)
# Out:
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/1.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/2.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/3.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/4.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/5.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/6.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/7.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/8.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/9.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/optometry/10.txt
# ...

# %%
# dermatology

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/dermatology_train.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/dermatology'

# Call the function to create individual files
create_individual_files(input_file, output_dir)

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/dermatology_test.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology'

# Call the function to create individual files
create_individual_files(input_file, output_dir)

# %%
# family medicine

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/family_medicine_train.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/train/family_medicine'

# Call the function to create individual files
create_individual_files(input_file, output_dir)

input_file = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/family_medicine_test.txt'
output_dir = 'C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/family_medicine'

# Call the function to create individual files
create_individual_files(input_file, output_dir)
# Out:
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/1.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/2.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/3.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/4.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/5.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/6.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/7.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/8.txt
# Created C:/Users/jhuff19/Desktop/Baymax/classification/classification_data/test/dermatology/9.txt
# ...
